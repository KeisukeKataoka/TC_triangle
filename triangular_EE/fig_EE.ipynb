# %%
import numpy as np
import matplotlib.pyplot as plt

p_list1,EE1,varEE,errEE = np.loadtxt("./Ax=4_Ay=6_P=24_L=144_T=576.lst",dtype='complex', skiprows=0, unpack=True)
#p_list2,EE2 = np.loadtxt("./L=420_al=21_half-EE_v1.lst",dtype='complex', skiprows=0, unpack=True)

fig, ax = plt.subplots(figsize=(3,2.5))
ax.set_xlabel(r'$p_g$',fontsize=16)  # x軸ラベル
#ax.set_xlabel('$$')  # x軸ラベル
ax.set_ylabel(r'$S_{\rm half}$',fontsize=16)  # y軸ラベル
#ax.set_xscale('log')
#ax.set_yscale('log')
ax.tick_params(labelsize=14,colors = "blue")
#ax.set_title('Energy') # グラフタイトル
# ax.set_aspect('equal') # スケールを揃える
#ax.grid()            # 罫線
#ax.set_xlim([0, 20]) # x方向の描画範囲を指定
#ax.set_ylim([0,21])    # y方向の描画範囲を指定
#ax.plot(p_list1,errEE,'o',linestyle='solid',label=r'$L_x=3,L_y=4$')
ax.plot(p_list1,EE1,'o',linestyle='solid',label=r'$L_x=3,L_y=4$')
#ax.errorbar(p_list1,EE1,yerr=errEE, marker='<', capthick=1, capsize=8, lw=1,label=r'$L_x=3,L_y=4$')
#ax.errorbar(p_list2,SG2,yerr=SGd2, marker='v', capthick=1, capsize=8, lw=1,label=r'$L_x=20$')
#ax.axhline(y=0.855, xmin=0, xmax=100, color='r',linestyle='dashed')
#ax.axhline(y=0.76502613805585, xmin=0, xmax=100, color='r',linestyle='dashed')
ax.legend(loc=0)    # 凡例
#ax.legend(loc='upper left', bbox_to_anchor=(1,1))    # 凡例
fig.tight_layout()  # レイアウトの設定
#plt.savefig('EE_0.5L_al=20.svg') # 画像の保存
plt.show()
# Out:
# /home/kataoka/anaconda3/lib/python3.11/site-packages/matplotlib/cbook.py:1709: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /home/kataoka/anaconda3/lib/python3.11/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
