# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import os

cmap = plt.colormaps['gnuplot']

# ファイル名を指定
filename = "Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal5.npz"
print("見つかったファイル:", filename)

# 情報抽出
match = re.search(r"Lx_(\d+)_Nd_(\d+)_NT_(\d+)_pz_([0-9.]+)_", filename)
if match:
    Lx = int(match.group(1))
    Nd = int(match.group(2))
    NT = int(match.group(3))
    pz = float(match.group(4))
    title_suffix = f"Lx={Lx}, Nd={Nd}, NT={NT}, pz={pz}"
else:
    title_suffix = os.path.basename(filename)

# 読み込みとプロット
with np.load(filename) as data:
    pg = data['pg']
    TEE1_ave = data['TEE1_ave']
    TEE1_err = data['TEE1_err']
    TEE1_var = data['TEE1_var']
    TEE2_ave = data['TEE2_ave']
    TEE2_err = data['TEE2_err']
    TEE2_var = data['TEE2_var']
    TEE3_ave = data['TEE3_ave']
    TEE3_err = data['TEE3_err']
    TEE3_var = data['TEE3_var']
    TEE4_ave = data['TEE4_ave']
    TEE4_err = data['TEE4_err']
    TEE4_var = data['TEE4_var']

label1 = f"Lx={Lx}_TEE1"
label2 = f"Lx={Lx}_TEE2"
label3 = f"Lx={Lx}_TEE3"
label4 = f"Lx={Lx}_TEE4"

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# 平均と誤差
ax[0].errorbar(pg, TEE1_ave, yerr=TEE1_err, fmt='o-', capsize=5, label=label1)
ax[0].errorbar(pg, TEE2_ave, yerr=TEE2_err, fmt='o-', capsize=5, label=label2)
ax[0].errorbar(pg, TEE3_ave, yerr=TEE3_err, fmt='o-', capsize=5, label=label3)
ax[0].errorbar(pg, TEE4_ave, yerr=TEE4_err, fmt='o-', capsize=5, label=label4)

# 分散
ax[1].plot(pg, TEE1_var, 's--', label=label1)
ax[1].plot(pg, TEE2_var, 's--', label=label2)
ax[1].plot(pg, TEE3_var, 's--', label=label3)
ax[1].plot(pg, TEE4_var, 's--', label=label4)

# 描画設定
ax[0].set_xlabel('$p_g$')
ax[0].set_ylabel('TEE')
ax[0].set_ylim(-1, 0.3)
ax[0].set_title(title_suffix)
ax[0].grid(True)
ax[0].legend()

ax[1].set_xlabel('$p_g$')
ax[1].set_ylabel('Variance of TEE')
ax[1].set_title(title_suffix + ", variance")
ax[1].grid(True)
ax[1].legend()

plt.tight_layout()
plt.savefig(f"pz_{pz}_Lx_{Lx}_Nd_{Nd}_NT_{NT}_MPI_hexagonal5.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 見つかったファイル: Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal5.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
import re
import os

cmap = plt.colormaps['gnuplot']

# ファイル名を指定
filename = "Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal1234_v3.npz"
print("見つかったファイル:", filename)

# 情報抽出
match = re.search(r"Lx_(\d+)_Nd_(\d+)_NT_(\d+)_pz_([0-9.]+)_", filename)
if match:
    Lx = int(match.group(1))
    Nd = int(match.group(2))
    NT = int(match.group(3))
    pz = float(match.group(4))
    title_suffix = f"Lx={Lx}, Nd={Nd}, NT={NT}, pz={pz}"
else:
    title_suffix = os.path.basename(filename)

# 読み込みとプロット
with np.load(filename) as data:
    pg = data['pg']
    TEE1_ave = data['TEE1_ave']
    TEE1_err = data['TEE1_err']
    TEE1_var = data['TEE1_var']
    TEE2_ave = data['TEE2_ave']
    TEE2_err = data['TEE2_err']
    TEE2_var = data['TEE2_var']
    TEE3_ave = data['TEE3_ave']
    TEE3_err = data['TEE3_err']
    TEE3_var = data['TEE3_var']
    TEE4_ave = data['TEE4_ave']
    TEE4_err = data['TEE4_err']
    TEE4_var = data['TEE4_var']

label1 = f"Lx={Lx}_TEE1"
label2 = f"Lx={Lx}_TEE2"
label3 = f"Lx={Lx}_TEE3"
label4 = f"Lx={Lx}_TEE4"

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

# 平均と誤差
ax[0].errorbar(pg, TEE1_ave, yerr=TEE1_err, fmt='o-', capsize=5, label=label1)
ax[0].errorbar(pg, TEE2_ave, yerr=TEE2_err, fmt='o-', capsize=5, label=label2)
ax[0].errorbar(pg, TEE3_ave, yerr=TEE3_err, fmt='o-', capsize=5, label=label3)
ax[0].errorbar(pg, TEE4_ave, yerr=TEE4_err, fmt='o-', capsize=5, label=label4)

# 分散
ax[1].plot(pg, TEE1_var, 's--', label=label1)
ax[1].plot(pg, TEE2_var, 's--', label=label2)
ax[1].plot(pg, TEE3_var, 's--', label=label3)
ax[1].plot(pg, TEE4_var, 's--', label=label4)

# 描画設定
ax[0].set_xlabel('$p_g$')
ax[0].set_ylabel('TEE')
ax[0].set_ylim(-1, 0.3)
ax[0].set_title(title_suffix)
ax[0].grid(True)
ax[0].legend()

ax[1].set_xlabel('$p_g$')
ax[1].set_ylabel('Variance of TEE')
ax[1].set_title(title_suffix + ", variance")
ax[1].grid(True)
ax[1].legend()

plt.tight_layout()
plt.savefig(f"pz_{pz}_Lx_{Lx}_Nd_{Nd}_NT_{NT}_MPI_hexagonal1234_v3.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 見つかったファイル: Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal1234_v3.npz

# %%
import numpy as np

data = np.load("Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal1234_v3.npz")
print(data.files)  # 保存されているキーの一覧を表示
data = np.load("Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal5.npz")
print(data.files)  # 保存されているキーの一覧を表示
data.close()
# Out:
# ['pg', 'TEE1_ave', 'TEE1_err', 'TEE1_var', 'TEE2_ave', 'TEE2_err', 'TEE2_var', 'TEE3_ave', 'TEE3_err', 'TEE3_var', 'TEE4_ave', 'TEE4_err', 'TEE4_var']
# ['pg', 'TEE1_ave', 'TEE1_err', 'TEE1_var', 'TEE2_ave', 'TEE2_err', 'TEE2_var', 'TEE3_ave', 'TEE3_err', 'TEE3_var', 'TEE4_ave', 'TEE4_err', 'TEE4_var']

# %%
import numpy as np

data = np.load("Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal1234_v3.npz")
print(data['pg'])
print(data['TEE1_ave'])
print(data['TEE1_err'])
print(data['TEE1_var'])
print(data['TEE2_ave'])
print(data['TEE2_err'])
print(data['TEE2_var'])
print(data['TEE3_ave'])
print(data['TEE3_err'])
print(data['TEE3_var'])
print(data['TEE4_ave'])
print(data['TEE4_err'])
print(data['TEE4_var'])
data.close()
# Out:
# [0.7  0.71 0.72 0.73 0.74 0.75 0.76 0.77 0.78 0.79 0.8  0.81 0.82 0.83
#  0.84 0.85 0.86 0.87 0.88 0.89 0.9 ]
#  4.46604745e-02 4.96526651e-02 2.95948478e-02 1.56186302e-02
#  8.35328916e-03 3.45411632e-03 1.37607465e-03 1.05129552e-03
#  5.63139660e-04 2.64276813e-04 9.85360725e-05 3.92119985e-05
#  3.29930556e-05]
# [ 0.0515      0.01131944  0.01429167  0.01744444  0.01558333  0.00895833
#  -0.01580556 -0.07541667 -0.20388889 -0.39038889 -0.61468056 -0.76736111
#  -0.87165278 -0.93101389 -0.96384722 -0.97509722 -0.98645833 -0.99231944
#  -0.99608333 -0.99809722 -0.99879167]
# [0.00374849 0.00128798 0.00154586 0.00168808 0.00198027 0.00255951
#  0.00399908 0.00643942 0.00917769 0.01135612 0.01021341 0.00779573
#  0.00555352 0.00336398 0.00204819 0.00164061 0.00113389 0.00074861
#  0.00046256 0.00025081 0.00017688]
# [7.01152315e-03 8.27792245e-04 1.19244965e-03 1.42196451e-03
#  1.95681250e-03 3.26899595e-03 7.98031559e-03 2.06915702e-02
#  4.20307870e-02 6.43517238e-02 5.20525561e-02 3.03259066e-02
#  1.53899342e-02 5.64687712e-03 2.09334317e-03 1.34310397e-03
#  6.41565394e-04 2.79647184e-04 1.06766204e-04 3.13910108e-05
#  1.56116898e-05]

# %%
import numpy as np

data = np.load("Lx_12_Nd_500_NT_4320_pz_0.0_MPI_hexagonal5.npz")
print(data['pg'])
print(data['TEE1_ave'])
print(data['TEE1_err'])
print(data['TEE1_var'])
print(data['TEE2_ave'])
print(data['TEE2_err'])
print(data['TEE2_var'])
print(data['TEE3_ave'])
print(data['TEE3_err'])
print(data['TEE3_var'])
print(data['TEE4_ave'])
print(data['TEE4_err'])
print(data['TEE4_var'])
data.close()
# Out:
# [0.7  0.71 0.72 0.73 0.74 0.75 0.76 0.77 0.78 0.79 0.8  0.81 0.82 0.83
#  0.84 0.85 0.86 0.87 0.88 0.89 0.9 ]
# [-0.09329167 -0.07916667 -0.11040278 -0.15669444 -0.21719444 -0.30184722
#  -0.398625   -0.50484722 -0.62344444 -0.70958333 -0.79955556 -0.85488889
#  -0.89443056 -0.92248611 -0.94704167 -0.95811111 -0.96954167 -0.97872222
#  -0.98627778 -0.99065278 -0.99325   ]
# [0.00417669 0.00306076 0.00363796 0.00441669 0.00509032 0.00605157
#  0.0063002  0.006191   0.00564948 0.00525419 0.00361635 0.00289481
#  0.00251639 0.00189904 0.00135686 0.00125522 0.0010645  0.00087267
#  0.0006066  0.000523   0.00037656]
# [8.70494039e-03 4.67476852e-03 6.60414718e-03 9.73408102e-03
#  1.29297755e-02 1.82741534e-02 1.98065392e-02 1.91259064e-02
#  1.59263997e-02 1.37756366e-02 6.52592130e-03 4.18157716e-03
#  3.15977990e-03 1.79956385e-03 9.18698110e-04 7.86216049e-04
#  5.65441937e-04 3.80010802e-04 1.83614198e-04 1.36491319e-04
#  7.07569444e-05]
# [-6.61111111e-03  2.31944444e-03 -9.86111111e-04 -1.54444444e-02
